# %% [markdown]
# <center>
#
# # <font colour = 'red'> **FIFA 2021 Data - Data Cleaning Using Python**</font>
#
# ---

# %%
from google.colab import userdata
import os

os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')
os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import kaggle
# import zipfile library to extract the file downloaded from Kaggle
import zipfile

# to use regex
import re

# %%
# !kaggle datasets download -d yagunnersya/fifa-21-messy-raw-dataset-for-cleaning-exploring
# Out:
# Dataset URL: https://www.kaggle.com/datasets/yagunnersya/fifa-21-messy-raw-dataset-for-cleaning-exploring
# License(s): CC0-1.0
# fifa-21-messy-raw-dataset-for-cleaning-exploring.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# extracting the file from the downloaded zip
with zipfile.ZipFile('/content/fifa-21-messy-raw-dataset-for-cleaning-exploring.zip','r') as file:
    file.extractall()

# %%
df = pd.read_csv('/content/fifa21 raw data v2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %%
# duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
def null_counter(x):
  col=x.columns
  print('Null values in the dataframe for each column is ')
  for i in col:

    print(f'{i} : ',x[i].isna().sum())

null_counter(df)
# Out:
# Null values in the dataframe for each column is
# ID :  0
# Name :  0
# LongName :  0
# Nationality :  0
# Age :  0
# Overall_Rating :  0
# Potential :  0
# Club :  0
# Contract :  0
# Positions :  0
# Height :  0
# Weight :  0
# Preferred Foot :  0
# BOV :  0
# Best Position :  0
# Joined :  0
# Loan Date End :  17966
# Value :  0
# Wage :  0
# Release Clause :  0
# Attacking :  0
# Crossing :  0
# Finishing :  0
# Heading Accuracy :  0
# Short Passing :  0
# Volleys :  0
# Skill :  0
# Dribbling :  0
# Curve :  0
# FK Accuracy :  0
# Long Passing :  0
# Ball Control :  0
# Movement :  0
# Acceleration :  0
# Sprint Speed :  0
# Agility :  0
# Reactions :  0
# Balance :  0
# Power :  0
# Shot Power :  0
# Jumping :  0
# Stamina :  0
# Strength :  0
# Long Shots :  0
# Mentality :  0
# Aggression :  0
# Interceptions :  0
# Positioning :  0
# Vision :  0
# Penalties :  0
# Composure :  0
# Defending :  0
# Marking :  0
# Standing Tackle :  0
# Sliding Tackle :  0
# Goalkeeping :  0
# ...

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
# from the visual it is obvious that we might not need photo and player urls for any kind of analysis so lets drop them
df.drop(columns = ['photoUrl','playerUrl'], inplace = True)

# %%
df.rename( columns = {'IR' : "International_Rating",
                      'W/F' : 'Weak_Foot_Rating',
                      'SM': 'Skill_Moves_Rating',
                      '↓OVA' : 'Overall_Rating',
                      'POT' : 'Potential'}, inplace = True)

# %%
df.head(3)
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
#
#    Overall_Rating  Potential                     Club     Contract  \
# 0              93         93     \n\n\n\nFC Barcelona  2004 ~ 2021
# 1              92         92         \n\n\n\nJuventus  2018 ~ 2022
# 2              91         93  \n\n\n\nAtlético Madrid  2014 ~ 2023
#
#     Positions  ...     A/W     D/W International_Rating  PAC SHO PAS DRI DEF  \
# 0  RW, ST, CF  ...  Medium     Low                  5 ★   85  92  91  95  38
# 1      ST, LW  ...    High     Low                  5 ★   89  93  81  89  35
# 2          GK  ...  Medium  Medium                  3 ★   87  92  78  90  52
#
#   PHY Hits
# 0  65  771
# 1  77  562
# 2  90  150
#
# [3 rows x 75 columns]

# %%
df['Club'].value_counts()
# Out:
# Club
# No Club                           237
# \n\n\n\nFC Barcelona               33
# \n\n\n\nBurnley                    33
# \n\n\n\nRC Celta                   33
# \n\n\n\nTorino                     33
#                                  ...
# \n\n\n\nMelbourne Victory          18
# \n\n\n\nBrisbane Roar              18
# \n\n\n\nAdelaide United            18
# \n\n\n\nPerth Glory                18
# \n\n\n\nCentral Coast Mariners     18
# Name: count, Length: 682, dtype: int64

# %%
df2 = df.copy()

# %%
df['Club'] = df["Club"].str.strip().str.replace('\n','')

# %%
df['Club'].head(10)
# Out:
# 0           FC Barcelona
# 1               Juventus
# 2        Atlético Madrid
# 3        Manchester City
# 4    Paris Saint-Germain
# 5      FC Bayern München
# 6              Liverpool
# 7              Liverpool
# 8    Paris Saint-Germain
# 9           FC Barcelona
# Name: Club, dtype: object

# %%
df['Contract'].unique()
# Out:
# array(['2004 ~ 2021', '2018 ~ 2022', '2014 ~ 2023', '2015 ~ 2023',
#        '2017 ~ 2022', '2017 ~ 2023', '2018 ~ 2024', '2014 ~ 2022',
#        '2018 ~ 2023', '2016 ~ 2023', '2013 ~ 2023', '2011 ~ 2023',
#        '2009 ~ 2022', '2005 ~ 2021', '2011 ~ 2021', '2015 ~ 2022',
#        '2017 ~ 2024', '2010 ~ 2024', '2012 ~ 2021', '2019 ~ 2024',
#        '2015 ~ 2024', '2017 ~ 2025', '2020 ~ 2025', '2019 ~ 2023',
#        '2008 ~ 2023', '2015 ~ 2021', '2020 ~ 2022', '2012 ~ 2022',
#        '2016 ~ 2025', '2013 ~ 2022', '2011 ~ 2022', '2012 ~ 2024',
#        '2016 ~ 2021', '2012 ~ 2023', '2008 ~ 2022', '2019 ~ 2022',
#        '2017 ~ 2021', '2013 ~ 2024', '2020 ~ 2024', '2010 ~ 2022',
#        '2020 ~ 2021', '2011 ~ 2024', '2020 ~ 2023', '2014 ~ 2024',
#        '2013 ~ 2026', '2016 ~ 2022', '2010 ~ 2021', '2013 ~ 2021',
#        '2019 ~ 2025', '2018 ~ 2025', '2016 ~ 2024', '2018 ~ 2021',
#        '2009 ~ 2024', '2007 ~ 2022', 'Jun 30, 2021 On Loan',
# ...

# %%
def contract_start_year(x):
  if x == 'Free':
    return 'Free'
  elif "On Loan" in x:
    return "On Loan"
  else:
    match = re.search('(\d{4})\s*', x)
    if match:
      return match.group()
    else:
      return None
df['contract_start_year'] = df['Contract'].apply(contract_start_year)
df.head(2)
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
#
#    Overall_Rating  Potential          Club     Contract   Positions  ...  D/W  \
# 0              93         93  FC Barcelona  2004 ~ 2021  RW, ST, CF  ...  Low
# 1              92         92      Juventus  2018 ~ 2022      ST, LW  ...  Low
#
#   International_Rating PAC  SHO PAS DRI DEF PHY Hits contract_start_year
# 0                  5 ★  85   92  91  95  38  65  771               2004
# 1                  5 ★  89   93  81  89  35  77  562               2018
#
# [2 rows x 76 columns]

# %%
def contract_end_year(x):
  if x == 'Free':
    return 'Free'
  elif "On Loan" in x:
    return "On Loan"
  else:
    match = re.search('\d{4}$', x)
    if match:
      return match.group()
    else:
      return None
df['contract_end_year'] = df['Contract'].apply(contract_end_year)
df.head(2)
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
#
#    Overall_Rating  Potential          Club     Contract   Positions  ...  \
# 0              93         93  FC Barcelona  2004 ~ 2021  RW, ST, CF  ...
# 1              92         92      Juventus  2018 ~ 2022      ST, LW  ...
#
#   International_Rating PAC SHO  PAS DRI DEF PHY Hits contract_start_year  \
# 0                  5 ★  85  92   91  95  38  65  771               2004
# 1                  5 ★  89  93   81  89  35  77  562               2018
#
#   contract_end_year
# 0              2021
# 1              2022
#
# [2 rows x 77 columns]

# %%
df['Height'].unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '6\'2"', '164cm', '198cm', '6\'3"', '6\'5"', '5\'11"',
#        '6\'4"', '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"',
#        '5\'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#        '157cm', '156cm', '202cm', '159cm', '206cm', '155cm'], dtype=object)

# %%
df['Weight'].unique()
# Out:
# array(['72kg', '83kg', '87kg', '70kg', '68kg', '80kg', '71kg', '91kg',
#        '73kg', '85kg', '92kg', '69kg', '84kg', '96kg', '81kg', '82kg',
#        '75kg', '86kg', '89kg', '74kg', '76kg', '64kg', '78kg', '90kg',
#        '66kg', '60kg', '94kg', '79kg', '67kg', '65kg', '59kg', '61kg',
#        '93kg', '88kg', '97kg', '77kg', '62kg', '63kg', '95kg', '100kg',
#        '58kg', '183lbs', '179lbs', '172lbs', '196lbs', '176lbs', '185lbs',
#        '170lbs', '203lbs', '168lbs', '161lbs', '146lbs', '130lbs',
#        '190lbs', '174lbs', '148lbs', '165lbs', '159lbs', '192lbs',
#        '181lbs', '139lbs', '154lbs', '157lbs', '163lbs', '98kg', '103kg',
#        '99kg', '102kg', '56kg', '101kg', '57kg', '55kg', '104kg', '107kg',
#        '110kg', '53kg', '50kg', '54kg', '52kg'], dtype=object)

# %%
def height_to_cm(x):
  if "\'" in x:
    feet,inches = x.split("\'")
    ht = int(round(int(feet)*30.48 + int(inches.strip('"'))*2.54,0))
  else:
    ht = int(x.strip('cm'))
  return ht

df['Height'] = df['Height'].apply(height_to_cm)

# %%
#since already the weight is converted to int with kgs, function will not run
def weight_to_kg(x):
  if "lbs" in x:
    weight = int(round(int(x.strip("lbs"))*0.453592 ,0))
  else:
    weight = int(x.strip('kg'))
  return weight

df['Weight'] = df['Weight'].apply(weight_to_kg)

# %%
df[['Height','Weight']].head(3)
# Out:
#    Height  Weight
# 0     170      72
# 1     187      83
# 2     188      87

# %%
df['International_Rating'].unique()
# Out:
# array(['5 ★', '3 ★', '4 ★', '2 ★', '1 ★'], dtype=object)

# %%
df['International_Rating'] = pd.to_numeric(df['International_Rating'].str.replace('★',''))

# %%
df['Skill_Moves_Rating'] = pd.to_numeric(df['Skill_Moves_Rating'].str.replace('★',''))
df['Weak_Foot_Rating'] = pd.to_numeric(df['Weak_Foot_Rating'].str.replace('★',''))

# %%
df.isna().sum()
# Out:
# ID                        0
# Name                      0
# LongName                  0
# Nationality               0
# Age                       0
#                        ...
# DEF                       0
# PHY                       0
# Hits                   2595
# contract_start_year       0
# contract_end_year         0
# Length: 77, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'Nationality', 'Age', 'Overall_Rating',
#        'Potential', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'Weak_Foot_Rating', 'Skill_Moves_Rating', 'A/W', 'D/W',
# ...

# %%
df[['Name','Club','contract_start_year','contract_start_year','contract_end_year','Joined','Loan Date End','Value', 'Wage', 'Release Clause','Hits']].head(4)
# Out:
#                 Name             Club contract_start_year contract_start_year  \
# 0           L. Messi     FC Barcelona               2004                2004
# 1  Cristiano Ronaldo         Juventus               2018                2018
# 2           J. Oblak  Atlético Madrid               2014                2014
# 3       K. De Bruyne  Manchester City               2015                2015
#
#   contract_end_year        Joined Loan Date End    Value   Wage  \
# 0              2021   Jul 1, 2004           NaN  €103.5M  €560K
# 1              2022  Jul 10, 2018           NaN     €63M  €220K
# 2              2023  Jul 16, 2014           NaN    €120M  €125K
# 3              2023  Aug 30, 2015           NaN    €129M  €370K
#
#   Release Clause Hits
# 0        €138.4M  771
# 1         €75.9M  562
# 2        €159.4M  150
# 3          €161M  207

# %%
df['Value'].unique()
# Out:
# array(['€103.5M', '€63M', '€120M', '€129M', '€132M', '€111M', '€120.5M',
#        '€102M', '€185.5M', '€110M', '€113M', '€90.5M', '€82M', '€17.5M',
#        '€83.5M', '€33.5M', '€114.5M', '€78M', '€103M', '€109M', '€92M',
#        '€10M', '€76.5M', '€89.5M', '€87.5M', '€79.5M', '€124M', '€114M',
#        '€95M', '€92.5M', '€105.5M', '€88.5M', '€85M', '€81.5M', '€26M',
#        '€21M', '€56M', '€67.5M', '€53M', '€36.5M', '€51M', '€65.5M',
#        '€46.5M', '€61.5M', '€72.5M', '€77.5M', '€43.5M', '€32.5M', '€36M',
#        '€32M', '€54M', '€49.5M', '€57M', '€66.5M', '€74.5M', '€71.5M',
#        '€121M', '€99M', '€67M', '€86.5M', '€93.5M', '€70M', '€62M',
#        '€66M', '€58M', '€44M', '€81M', '€37M', '€14.5M', '€46M', '€47.5M',
#        '€52.5M', '€54.5M', '€34.5M', '€57.5M', '€51.5M', '€44.5M', '€55M',
#        '€48M', '€60.5M', '€63.5M', '€61M', '€29M', '€58.5M', '€55.5M',
#        '€42M', '€40.5M', '€43M', '€45.5M', '€34M', '€26.5M', '€42.5M',
# ...

# %%
def value_to_euros(x):
  multipler=1
  if 'M' in x:
    multipler = 1000000
  elif 'K' in x:
    multipler = 1000
  value = x.strip('€').replace('M','').replace('K','')
  return int(float(value)*multipler)

df['Value'] = df['Value'].apply(value_to_euros)
#print(value_to_euros('€33.5M'))

# %%
df['Wage'].unique()
# Out:
# array(['€560K', '€220K', '€125K', '€370K', '€270K', '€240K', '€250K',
#        '€160K', '€260K', '€210K', '€310K', '€130K', '€350K', '€300K',
#        '€190K', '€145K', '€195K', '€100K', '€140K', '€290K', '€82K',
#        '€110K', '€230K', '€155K', '€200K', '€165K', '€95K', '€170K',
#        '€105K', '€115K', '€150K', '€135K', '€55K', '€58K', '€81K', '€34K',
#        '€120K', '€59K', '€90K', '€65K', '€56K', '€71K', '€18K', '€75K',
#        '€47K', '€20K', '€84K', '€86K', '€74K', '€78K', '€27K', '€68K',
#        '€85K', '€25K', '€46K', '€83K', '€54K', '€79K', '€175K', '€43K',
#        '€49K', '€45K', '€38K', '€41K', '€39K', '€23K', '€51K', '€50K',
#        '€87K', '€30K', '€14K', '€69K', '€31K', '€64K', '€53K', '€35K',
#        '€21K', '€28K', '€17K', '€33K', '€70K', '€32K', '€89K', '€26K',
#        '€40K', '€76K', '€72K', '€48K', '€36K', '€29K', '€60K', '€16K',
#        '€37K', '€24K', '€52K', '€0', '€62K', '€73K', '€63K', '€19K',
# ...

# %%
def wage_to_euros(x):
    multiplier = 1
    if 'K' in x:
      multiplier = 1000
    wage = x.strip('€').replace('K','')
    return int(wage)*multiplier

df['Wage'] = df['Wage'].apply(wage_to_euros)

# %%
df['Release Clause'].unique()
# Out:
# array(['€138.4M', '€75.9M', '€159.4M', ..., '€59K', '€35K', '€64K'],
#       dtype=object)

# %%
# Function to check if a column contains 'K' or 'M'
def column_contains_K_or_M(col):
    return col.astype(str).str.contains('K|M').any()

columns_without_K_or_M = [col for col in df.columns if not column_contains_K_or_M(df['Release Clause'])]

# Display the columns
print("Columns without 'K' or 'M':", columns_without_K_or_M)
# Out:
# Columns without 'K' or 'M': []

# %%
def rc_to_euros(x):
  multipler=1
  if 'M' in x:
    multipler = 1000000
  elif 'K' in x:
    multipler = 1000
  value = x.strip('€').replace('M','').replace('K','')
  return int(float(value)*multipler)

df['Release Clause'] = df['Release Clause'].apply(rc_to_euros)
#print(rc_to_euros('€59K'))

# %%
df['Release Clause'].head(3)
# Out:
# 0    138400000
# 1     75900000
# 2    159400000
# Name: Release Clause, dtype: int64

# %%
df.rename(columns= {'Value' : 'Value (Euros)','Release Clause' : 'Release Clause (Euros)','Wage' : 'Wage (Euros)'}, inplace = True)

# %%
df['Loan Date End'].unique()
# Out:
# array([nan, 'Jun 30, 2021', 'Dec 31, 2020', 'Jan 30, 2021',
#        'Jun 30, 2022', 'May 31, 2021', 'Jul 5, 2021', 'Dec 31, 2021',
#        'Jul 1, 2021', 'Jan 1, 2021', 'Aug 31, 2021', 'Jan 31, 2021',
#        'Dec 30, 2021', 'Jun 23, 2021', 'Jan 3, 2021', 'Nov 27, 2021',
#        'Jan 17, 2021', 'Jun 30, 2023', 'Jul 31, 2021', 'Nov 22, 2020',
#        'May 31, 2022', 'Dec 30, 2020', 'Jan 4, 2021', 'Nov 30, 2020',
#        'Aug 1, 2021'], dtype=object)

# %%
pd.to_datetime('Jan 4, 2021').dt.date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-1dae07d00b07> in <cell line: 1>()
# ----> 1 pd.to_datetime('Jan 4, 2021').dt.date
#
# AttributeError: 'Timestamp' object has no attribute 'dt'

# %%
df['Joined'].unique()
# Out:
# array(['Jul 1, 2004', 'Jul 10, 2018', 'Jul 16, 2014', ..., 'Sep 22, 2018',
#        'Feb 28, 2015', 'Mar 6, 2018'], dtype=object)

# %%
df2['date_column2'] = pd.to_datetime(df['Loan Date End'], format='%b %d, %Y').dt.date

# %%
df2['date_column2'].unique()
# Out:
# array([NaT, datetime.date(2021, 6, 30), datetime.date(2020, 12, 31),
#        datetime.date(2021, 1, 30), datetime.date(2022, 6, 30),
#        datetime.date(2021, 5, 31), datetime.date(2021, 7, 5),
#        datetime.date(2021, 12, 31), datetime.date(2021, 7, 1),
#        datetime.date(2021, 1, 1), datetime.date(2021, 8, 31),
#        datetime.date(2021, 1, 31), datetime.date(2021, 12, 30),
#        datetime.date(2021, 6, 23), datetime.date(2021, 1, 3),
#        datetime.date(2021, 11, 27), datetime.date(2021, 1, 17),
#        datetime.date(2023, 6, 30), datetime.date(2021, 7, 31),
#        datetime.date(2020, 11, 22), datetime.date(2022, 5, 31),
#        datetime.date(2020, 12, 30), datetime.date(2021, 1, 4),
#        datetime.date(2020, 11, 30), datetime.date(2021, 8, 1)],
#       dtype=object)

# %%
df2[df2['date_column2'] == 'datetime.date(2021, 6, 30)']
# Out:
# Empty DataFrame
# Columns: [ID, Name, LongName, Nationality, Age, Overall_Rating, Potential, Club, Contract, Positions, Height, Weight, Preferred Foot, BOV, Best Position, Joined, Loan Date End, Value, Wage, Release Clause, Attacking, Crossing, Finishing, Heading Accuracy, Short Passing, Volleys, Skill, Dribbling, Curve, FK Accuracy, Long Passing, Ball Control, Movement, Acceleration, Sprint Speed, Agility, Reactions, Balance, Power, Shot Power, Jumping, Stamina, Strength, Long Shots, Mentality, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Defending, Marking, Standing Tackle, Sliding Tackle, Goalkeeping, GK Diving, GK Handling, GK Kicking, GK Positioning, GK Reflexes, Total Stats, Base Stats, Weak_Foot_Rating, Skill_Moves_Rating, A/W, D/W, International_Rating, PAC, SHO, PAS, DRI, DEF, PHY, Hits, date_column, date_column2]
# Index: []
#
# [0 rows x 77 columns]
